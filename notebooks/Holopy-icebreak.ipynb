# %% [markdown]
# ## a test on holopy

# %%
# %matplotlib nbagg
from holopy import test_disp
test_disp()
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# <div id='3a30fff5-319f-4e34-bf07-4b727b88c347'></div>

# %%
# %matplotlib inline
import holopy as hp
from holopy.core.io import get_example_data_path
imagepath = get_example_data_path('image01.jpg')
raw_holo = hp.load_image(imagepath, spacing = 0.0851)
hp.show(raw_holo)
# Out:
# /opt/conda/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
# %matplotlib tk
# %matplotlib qt
# %matplotlib gtk
# %matplotlib gtk3
from holopy import test_disp
test_disp()
# Out:
# ...
# [66, 27, 0]

# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

A = np.fromfile("4phaseTargetFresnel_XY_D_2048_2048_8bit_e.raw", dtype='int8', sep="")

A = np.reshape(A, (2048, 2048, 4))
img_gray = np.dot(A[..., :3], [0.30, 0.59, 0.11])
plt.imshow(img_gray, cmap="gray")
plt.show()
